# %% [markdown]
# # Notebook Visualization
#
# Please follow link below to exercise notebook
#
# [LINK TO NOTEBOOK](http://nbviewer.jupyter.org/github/rsten/RSten.github.io/blob/master/Deep%20Learning/week3/lab3_RNN.ipynb)
